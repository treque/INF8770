# %% [markdown]
# INF8770 Technologies multimédias
#
# Polytechnique Montréal
#
# Exemple de codage par plage

# %%
import numpy as np
import import_ipynb
from Untitled import brel
from random import randrange
import timeit
# Out:
# importing Jupyter notebook from Untitled.ipynb

# %% [markdown]
# Message à coder et définition de la taille du compteur en bits

# %%
def messageGenerator(symbols):
    message = ""
    for i in range(10000):
        message += symbols[randrange(len(symbols))]
    return message

# %%
Messages = []
Symboles = ["A", "B", "C", "D", "E", "F", "G", "H"]
for i in range(1,9):
    Messages.append(messageGenerator(Symboles[0:i]))

# %%
compteur = 2 #La meilleure taille pour ce message est 2 bits. Plusieurs courtes répétitions
Message = brel

# %% [markdown]
# Construction du dictionnaire à partir des symboles contenus dans le message.

# %%
dictsymb =[Message[0]]
dictbin = ["{:b}".format(0)]
nbsymboles = 1
for i in range(1,len(Message)):
    if Message[i] not in dictsymb:
        dictsymb += [Message[i]]
        dictbin += ["{:b}".format(nbsymboles)] 
        nbsymboles +=1
longueurOriginale = np.ceil(np.log2(nbsymboles))*len(Message) #Longueur du message avec codage binaire

# %% [markdown]
# Ajustement des codes binaires selon le nombre total de symboles en ajoutant des zéros. Tri des symboles. Affichage du dictionnaire.

# %%
for i in range(nbsymboles):
    dictbin[i] = "{:b}".format(i).zfill(int(np.ceil(np.log2(nbsymboles))))
        
dictsymb.sort()
dictionnaire = np.transpose([dictsymb,dictbin])
print(dictionnaire)
# Out:
# [['\n' '000000']
#  [' ' '000001']
#  ['!' '000010']
#  ["'" '000011']
#  [',' '000100']
#  ['-' '000101']
#  ['.' '000110']
#  ['A' '000111']
#  ['B' '001000']
#  ['C' '001001']
#  ['D' '001010']
#  ['E' '001011']
#  ['F' '001100']
#  ['I' '001101']
#  ['J' '001110']
#  ['L' '001111']
#  ['M' '010000']
#  ['O' '010001']
#  ['P' '010010']
#  ['Q' '010011']
#  ['R' '010100']
#  ['S' '010101']
#  ['U' '010110']
#  ['V' '010111']
#  ['Y' '011000']
#  ['a' '011001']
#  ['b' '011010']
#  ['c' '011011']
#  ['d' '011100']
#  ['e' '011101']
#  ['f' '011110']
#  ['g' '011111']
#  ['h' '100000']
#  ['i' '100001']
#  ['j' '100010']
#  ['l' '100011']
#  ['m' '100100']
#  ['n' '100101']
#  ['o' '100110']
#  ['p' '100111']
#  ['q' '101000']
#  ['r' '101001']
#  ['s' '101010']
#  ['t' '101011']
#  ['u' '101100']
#  ['v' '101101']
#  ['x' '101110']
#  ['y' '101111']
#  ['z' '110000']
#  ['À' '110001']
#  ['à' '110010']
#  ['â' '110011']
#  ['ç' '110100']
#  ['è' '110101']
#  ['é' '110110']
#  ['ê' '110111']
#  ['î' '111000']
#  ['ô' '111001']
#  ['û' '111010']
#  ['œ' '111011']]

# %% [markdown]
# Codage du message

# %%
start = timeit.default_timer()
i=0;
MessageCode = []
longueur = 0
while i < len(Message):
    carac = Message[i] #caractere qui sera codé
    repetition = 1
    #Calcul le nombre de répétitions.
    i += 1
    #tient compte de la limite du compteur
    while i < len(Message) and repetition < 2**compteur and Message[i] == carac: 
        i += 1
        repetition += 1
    #Codage à l'aide du dictionnaire  
    coderepetition = "{:b}".format(repetition-1).zfill(compteur)
    codebinaire = dictbin[dictsymb.index(carac)]
    MessageCode += [coderepetition, codebinaire]
    longueur += len(codebinaire) + len(coderepetition)
stop = timeit.default_timer()
execution_time = stop - start

print("temps d'exec " + str(execution_time))
# Out:
# temps d'exec 0.018524900000000066

# %% [markdown]
# Affichage du message codé

# %%
print(MessageCode)
# Out:
# ['00', '001010', '00', '000011', '00', '011001', '00', '011010', '00', '100110', '00', '101001', '00', '011100', '10', '000110', '00', '000000', '00', '001010', '00', '000011', '00', '011001', '00', '011010', '00', '100110', '00', '101001', '00', '011100', '00', '000100', '00', '000001', '00', '101111', '00', '000011', '00', '011001', '00', '000001', '00', '100011', '00', '000011', '00', '011001', '00', '111000', '00', '100101', '00', '110110', '00', '000000', '00', '001111', '00', '101100', '00', '100001', '00', '000001', '00', '101000', '00', '101100', '00', '000011', '00', '011101', '00', '101010', '00', '101011', '00', '000001', '00', '011011', '00', '100110', '01', '100100', '00', '011101', '00', '000001', '00', '101100', '00', '100101', '00', '000001', '00', '100100', '00', '011101', '00', '100011', '00', '100110', '00', '100101', '00', '000000', '00', '001111', '00', '101100', '00', '100001', '00', '000001', '00', '101000', '00', '101100', '00', '100001', '00', '000001', '00', '011001', '00', '000001', '00', '101100', '00', '100101', '00', '000001', '00', '011111', '00', '101001', '00', '100110', '00', '101010', '00', '000001', '00', '100101', '00', '011101', '00', '110000', '00', '000000', '00', '001111', '00', '101100', '00', '100001', '00', '000001', '00', '101000', '00', '101100', '00', '100001', '00', '000001', '00', '101010', '00', '011001', '00', '100001', '00', '101011', '00', '000001', '00', '100111', '00', '100011', '00', '101100', '00', '101010', '00', '000001', '00', '101010', '00', '100110', '00', '100101', '00', '000001', '00', '100101', '00', '100110', '00', '100100', '00', '000100', '00', '000001', '00', '010000', '00', '100110', '00', '100101', '00', '101010', '00', '100001', '00', '011101', '00', '101100', '00', '101001', '00', '000100', '00', '000001', '00', '101011', '00', '011101', '01', '100011', '00', '011101', '00', '100100', '00', '011101', '00', '100101', '00', '101011', '00', '000001', '00', '101000', '00', '101100', '00', '000011', '00', '100001', '00', '100011', '00', '000001', '00', '011010', '00', '100110', '00', '100001', '00', '101011', '00', '000000', '00', '010001', '00', '101100', '00', '000001', '00', '101011', '00', '011101', '01', '100011', '00', '011101', '00', '100100', '00', '011101', '00', '100101', '00', '101011', '00', '000001', '00', '101000', '00', '101100', '00', '000011', '00', '100001', '00', '100011', '00', '000001', '00', '011001', '00', '000001', '00', '011010', '00', '101100', '00', '000000', '00', '010011', '00', '101100', '00', '100001', '00', '000001', '00', '011110', '00', '011001', '00', '100001', '00', '101011', '00', '000001', '00', '101001', '00', '100001', '00', '011101', '00', '100101', '00', '000001', '00', '011100', '00', '000011', '00', '101010', '00', '011101', '00', '101010', '00', '000001', '00', '011100', '00', '100001', '00', '101110', '00', '000001', '00', '011100', '00', '100110', '00', '100001', '00', '011111', '00', '101011', '00', '101010', '00', '000000', '00', '010000', '00', '011001', '00', '100001', '00', '101010', '00', '000001', '00', '100011', '00', '101100', '00', '100001', '00', '000001', '00', '101000', '00', '101100', '00', '100001', '00', '000001', '00', '100101', '00', '000011', '00', '011101', '00', '100101', '00', '000001', '00', '100111', '00', '011101', '00', '101100', '00', '101011', '00', '000001', '00', '100111', '00', '100011', '00', '101100', '00', '101010', '00', '000000', '00', '001111', '00', '101100', '00', '100001', '00', '000001', '00', '101000', '00', '101100', '00', '100001', '00', '000001', '00', '011101', '00', '101010', '00', '101011', '00', '000001', '00', '011011', '00', '100110', '00', '100100', '00', '100111', '00', '100011', '00', '110101', '00', '101011', '00', '011101', '00', '100100', '00', '011101', '00', '100101', '00', '101011', '00', '000001', '00', '011011', '00', '101100', '00', '100001', '00', '101011', '00', '000000', '00', '001011', '00', '101011', '00', '000001', '00', '101000', '00', '101100', ...

# %% [markdown]
# Longueur en bits du message codé et celle de l'original

# %%
print("Longueur = {0}".format(longueur))
print("Longueur originale = {0}".format(longueurOriginale))
# Out:
# Longueur = 21624
# Longueur originale = 16446.0

# %%
taux = 1 - longueur/longueurOriginale
print(taux)
# Out:
# -0.3148485954031375
