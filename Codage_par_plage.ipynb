# %% [markdown]
# INF8770 Technologies multimédias
#
# Polytechnique Montréal
#
# Exemple de codage par plage

# %%
import numpy as np
from random import randrange
import timeit

# %% [markdown]
# Message à coder et définition de la taille du compteur en bits

# %%
def messageGenerator(symbols):
    message = ""
    for i in range(10000):
        message += symbols[randrange(len(symbols))]
    return message

# %%
Messages = []
Symboles = ["A", "B", "C", "D", "E", "F", "G", "H"]
for i in range(1,9):
    Messages.append(messageGenerator(Symboles[0:i]))
print(Messages)
# Out:
# ['...', '...', '...', '...', '...', '...', '...', '...']

# %%
compteur = 2 #La meilleure taille pour ce message est 2 bits. Plusieurs courtes répétitions
Message = Messages[6]

# %% [markdown]
# Construction du dictionnaire à partir des symboles contenus dans le message.

# %%
dictsymb =[Message[0]]
dictbin = ["{:b}".format(0)]
nbsymboles = 1
for i in range(1,len(Message)):
    if Message[i] not in dictsymb:
        dictsymb += [Message[i]]
        dictbin += ["{:b}".format(nbsymboles)] 
        nbsymboles +=1
longueurOriginale = np.ceil(np.log2(nbsymboles))*len(Message) #Longueur du message avec codage binaire

# %% [markdown]
# Ajustement des codes binaires selon le nombre total de symboles en ajoutant des zéros. Tri des symboles. Affichage du dictionnaire.

# %%
for i in range(nbsymboles):
    dictbin[i] = "{:b}".format(i).zfill(int(np.ceil(np.log2(nbsymboles))))
        
dictsymb.sort()
dictionnaire = np.transpose([dictsymb,dictbin])
print(dictionnaire)
# Out:
# [['A' '000']
#  ['B' '001']
#  ['C' '010']
#  ['D' '011']
#  ['E' '100']
#  ['F' '101']]

# %% [markdown]
# Codage du message

# %%
start = timeit.default_timer()
i=0;
MessageCode = []
longueur = 0
while i < len(Message):
    carac = Message[i] #caractere qui sera codé
    repetition = 1
    #Calcul le nombre de répétitions.
    i += 1
    #tient compte de la limite du compteur
    while i < len(Message) and repetition < 2**compteur and Message[i] == carac: 
        i += 1
        repetition += 1
    #Codage à l'aide du dictionnaire  
    coderepetition = "{:b}".format(repetition-1).zfill(compteur)
    codebinaire = dictbin[dictsymb.index(carac)]
    MessageCode += [coderepetition, codebinaire]
    longueur += len(codebinaire) + len(coderepetition)
stop = timeit.default_timer()
execution_time = stop - start

print("temps d'exec " + str(execution_time))
# Out:
# temps d'exec 0.019627800000307616

# %% [markdown]
# Affichage du message codé

# %%
print(MessageCode)
# Out:
# ['00', '010', '00', '100', '00', '001', '00', '011', '00', '010', '00', '000', '01', '101', '00', '100', '00', '101', '00', '001', '00', '011', '00', '010', '00', '000', '00', '100', '00', '010', '00', '001', '01', '010', '00', '101', '00', '011', '01', '010', '01', '001', '00', '101', '00', '100', '01', '001', '00', '011', '00', '000', '00', '010', '01', '101', '00', '001', '00', '100', '00', '010', '00', '001', '00', '100', '00', '000', '10', '010', '00', '000', '00', '101', '00', '011', '00', '101', '00', '001', '01', '101', '00', '011', '00', '010', '10', '001', '00', '010', '01', '101', '00', '011', '00', '000', '00', '001', '01', '011', '01', '100', '00', '000', '00', '001', '00', '101', '00', '100', '00', '010', '00', '001', '00', '010', '00', '000', '00', '011', '00', '010', '00', '100', '00', '101', '01', '100', '00', '011', '01', '000', '01', '010', '00', '000', '00', '101', '00', '010', '00', '011', '00', '010', '00', '100', '00', '001', '00', '010', '00', '000', '00', '010', '00', '011', '00', '100', '00', '101', '11', '000', '00', '011', '00', '101', '00', '000', '00', '100', '00', '011', '00', '101', '00', '100', '00', '000', '01', '011', '00', '010', '00', '011', '00', '001', '00', '011', '00', '001', '00', '100', '00', '011', '00', '100', '00', '011', '00', '101', '00', '001', '00', '010', '00', '101', '00', '001', '00', '101', '00', '001', '00', '101', '00', '011', '00', '001', '00', '101', '00', '000', '01', '001', '01', '101', '00', '000', '00', '100', '01', '001', '01', '101', '00', '001', '00', '010', '00', '000', '00', '011', '01', '100', '01', '010', '00', '011', '00', '000', '00', '001', '01', '101', '00', '010', '00', '101', '01', '010', '00', '011', '00', '100', '00', '010', '00', '000', '00', '100', '00', '011', '01', '101', '00', '000', '00', '101', '00', '010', '00', '001', '00', '000', '00', '001', '00', '011', '01', '100', '01', '010', '00', '101', '00', '100', '01', '101', '00', '001', '00', '000', '00', '101', '00', '011', '00', '100', '10', '000', '00', '011', '01', '100', '00', '011', '00', '100', '00', '001', '00', '101', '00', '100', '00', '011', '00', '101', '00', '100', '00', '011', '00', '101', '00', '100', '01', '010', '00', '000', '00', '001', '00', '101', '00', '011', '00', '101', '00', '010', '00', '100', '00', '000', '01', '101', '01', '011', '00', '001', '00', '101', '01', '011', '00', '101', '00', '011', '01', '101', '00', '011', '00', '100', '11', '000', '00', '011', '00', '000', '01', '101', '00', '000', '00', '010', '00', '101', '00', '011', '00', '001', '00', '011', '01', '001', '00', '010', '00', '100', '01', '101', '00', '011', '00', '010', '10', '001', '00', '010', '00', '101', '00', '010', '00', '000', '00', '010', '00', '001', '00', '010', '10', '101', '00', '001', '01', '010', '00', '001', '00', '010', '00', '001', '00', '100', '00', '010', '00', '001', '10', '100', '00', '000', '00', '010', '00', '000', '00', '100', '01', '011', '00', '100', '01', '001', '00', '101', '00', '100', '00', '101', '00', '010', '01', '000', '01', '001', '00', '010', '00', '001', '00', '101', '00', '001', '00', '101', '00', '010', '00', '100', '00', '101', '00', '011', '00', '001', '00', '100', '00', '000', '00', '011', '00', '010', '00', '101', '00', '001', '00', '010', '00', '000', '01', '011', '00', '000', '00', '011', '00', '010', '00', '000', '00', '100', '00', '101', '00', '011', '00', '100', '00', '011', '00', '010', '00', '000', '00', '011', '00', '000', '00', '101', '00', '000', '01', '100', '00', '001', '00', '010', '00', '100', '01', '001', '01', '100', '00', '011', '00', '101', '00', '010', '00', '000', '00', '010', '00', '011', '00', '000', '00', '101', '10', '010', '00', '000', '00', '101', '00', '011', '00', '000', '00', '101', '00', '000', '01', '001', '00', '010', '00', '101', '00', '010', '00', '001', '00', '000', '00', '011', '01', '010', '00', '100', '00', '001', '00', '011', '01', '001', '00', '101', '01', '010', '00', '101', '00', '011', '00', '010', '00', '011', '00', '0 ...

# %% [markdown]
# Longueur en bits du message codé et celle de l'original

# %%
print("Longueur = {0}".format(longueur))
print("Longueur originale = {0}".format(longueurOriginale))
# Out:
# Longueur = 41630
# Longueur originale = 30000.0

# %%
taux = 1 - longueur/longueurOriginale
print(taux)
# Out:
# -0.4566666666666668
